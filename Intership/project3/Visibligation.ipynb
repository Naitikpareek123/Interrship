# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
mark1=np.array([60,65,70,55,45,54])
mark2=np.array([55,70,40,50,55,57])


plt.subplot(2,2,1)
plt.plot(mark1,mark2)

mark1=np.array([60,65,70,55,45,54])
mark2=np.array([55,70,40,50,55,57])


plt.subplot(2,2,3)
plt.pie(mark1)


mark1=np.array([60,65,70,55,45,54])
mark2=np.array([55,70,40,50,55,57])


plt.subplot(2,2,2)
plt.bar(mark1,mark2)

mark1=np.array([60,65,70,55,45,54])
mark2=np.array([55,70,40,50,55,57])


plt.subplot(2,2,4)
plt.plot(mark1,mark2)

plt.show()

plt.hist(mark1)
# Out:
# (array([1., 0., 0., 1., 1., 0., 1., 0., 1., 1.]),
#  array([45. , 47.5, 50. , 52.5, 55. , 57.5, 60. , 62.5, 65. , 67.5, 70. ]),
#  <BarContainer object of 10 artists>)

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 2, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 2, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([2,5, 3, 8])

plt.subplot(2, 2, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([20,44, 69, 8])

plt.subplot(2, 2, 4)
plt.plot(x,y)

plt.show()
