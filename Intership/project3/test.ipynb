# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\91785\Documents\GitHub\Naitikpareek123\python\project3\IMDB-Movie-Data.csv")
print(data)
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
data.count()
# Out:
# Rank                  1000
# Title                 1000
# Genre                 1000
# Description           1000
# Director              1000
# Actors                1000
# Year                  1000
# Runtime (Minutes)     1000
# Rating                1000
# Votes                 1000
# Revenue (Millions)     872
# Metascore              936
# dtype: int64

# %%
data.sum()
# Out:
# Rank                                                             500500
# Title                 Guardians of the GalaxyPrometheusSplitSingSuic...
# Genre                 Action,Adventure,Sci-FiAdventure,Mystery,Sci-F...
# Description           A group of intergalactic criminals are forced ...
# Director              James GunnRidley ScottM. Night ShyamalanChrist...
# Actors                Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Year                                                            2012783
# Runtime (Minutes)                                                113172
# Rating                                                           6723.2
# Votes                                                         169808255
# Revenue (Millions)                                             72337.96
# Metascore                                                       55210.0
# dtype: object

# %%
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
data.describe().transpose()
# Out:
#                      count           mean            std     min       25%  \
# Rank                1000.0     500.500000     288.819436     1.0    250.75
# Year                1000.0    2012.783000       3.205962  2006.0   2010.00
# Runtime (Minutes)   1000.0     113.172000      18.810908    66.0    100.00
# Rating              1000.0       6.723200       0.945429     1.9      6.20
# Votes               1000.0  169808.255000  188762.647518    61.0  36309.00
# Revenue (Millions)   872.0      82.956376     103.253540     0.0     13.27
# Metascore            936.0      58.985043      17.194757    11.0     47.00
#
#                            50%         75%         max
# Rank                   500.500     750.250     1000.00
# Year                  2014.000    2016.000     2016.00
# Runtime (Minutes)      111.000     123.000      191.00
# Rating                   6.800       7.400        9.00
# Votes               110799.000  239909.750  1791916.00
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
data.describe(percentiles=[0.2,0.5,0.65,0.75])
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 20%     200.800000  2009.800000          97.000000     6.000000  2.608880e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 65%     650.350000  2015.000000         118.000000     7.100000  1.796793e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# ...

# %%
list(data.columns)
# Out:
# ['Rank',
#  'Title',
#  'Genre',
#  'Description',
#  'Director',
#  'Actors',
#  'Year',
#  'Runtime (Minutes)',
#  'Rating',
#  'Votes',
#  'Revenue (Millions)',
#  'Metascore']

# %% [markdown]
# data.isnull()

# %%
data.isnull()
# Out:
#       Rank  Title  Genre  Description  Director  Actors   Year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# ...

# %%
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
print(list(data.columns))   #only find only columns
# Out:
# ['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year', 'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)', 'Metascore']

# %%
data.shape
# Out:
# (1000, 12)

# %%
data.corr()  # IT use for correction in all data meaning relation b/w all columns
# Out:
# C:\Users\91785\AppData\Local\Temp\ipykernel_11620\517466308.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()  # IT use for correction in all data meaning relation b/w all columns
#                         Rank      Year  Runtime (Minutes)    Rating     Votes  \
# Rank                1.000000 -0.261605          -0.221739 -0.219555 -0.283876
# Year               -0.261605  1.000000          -0.164900 -0.211219 -0.411904
# Runtime (Minutes)  -0.221739 -0.164900           1.000000  0.392214  0.407062
# Rating             -0.219555 -0.211219           0.392214  1.000000  0.511537
# Votes              -0.283876 -0.411904           0.407062  0.511537  1.000000
# Revenue (Millions) -0.271592 -0.126790           0.267953  0.217654  0.639661
# ...

# %%
data.plot( 'Runtime (Minutes)' , 'Revenue (Millions)' )
# Out:
# <Axes: xlabel='Runtime (Minutes)'>

# %%
data.plot()
# Out:
# <Axes: >

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Rank'}>,
#         <Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Runtime (Minutes)'}>],
#        [<Axes: title={'center': 'Rating'}>,
#         <Axes: title={'center': 'Votes'}>,
#         <Axes: title={'center': 'Revenue (Millions)'}>],
#        [<Axes: title={'center': 'Metascore'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
data.hist(['Runtime (Minutes)' , 'Revenue (Millions)'] )
# Out:
# array([[<Axes: title={'center': 'Runtime (Minutes)'}>,
#         <Axes: title={'center': 'Revenue (Millions)'}>]], dtype=object)

# %%
data.plot(kind='hist',x='Year',y='Revenue (Millions)')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data["Runtime (Minutes)"].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.plot(kind='scatter',x='Runtime (Minutes)',  y='Revenue (Millions)')
# Out:
# <Axes: xlabel='Runtime (Minutes)', ylabel='Revenue (Millions)'>

# %%
data.plot(kind='scatter',x='Runtime (Minutes)',  y='Revenue (Millions)',figsize=(20,10))
# Out:
# <Axes: xlabel='Runtime (Minutes)', ylabel='Revenue (Millions)'>

# %%
data.plot(kind='box',x='Runtime (Minutes)',  y='Revenue (Millions)')
# Out:
# <Axes: >

# %%
data.plot(kind='bar',x='Runtime (Minutes)',  y='Revenue (Millions)')
# Out:
# <Axes: xlabel='Runtime (Minutes)'>

# %%
data.plot(kind='pie',x='Runtime (Minutes)',  y='Revenue (Millions)',figsize=(40,10))
# Out:
# <Axes: ylabel='Revenue (Millions)'>

# %%
data.plot(kind='hexbin',x='Runtime (Minutes)',  y='Revenue (Millions)')
# Out:
# <Axes: xlabel='Runtime (Minutes)', ylabel='Revenue (Millions)'>

# %%
data.plot(kind='area',x='Runtime (Minutes)',  y='Revenue (Millions)')
# Out:
# <Axes: xlabel='Runtime (Minutes)'>

# %%
data.plot(kind='barh',x='Runtime (Minutes)',  y='Revenue (Millions)')
# Out:
# <Axes: ylabel='Runtime (Minutes)'>

# %%
data.plot(kind='line',x='Title',  y='Year')
# Out:
# <Axes: xlabel='Title'>

# %%
data.hist('Rating')
# Out:
# array([[<Axes: title={'center': 'Rating'}>]], dtype=object)
